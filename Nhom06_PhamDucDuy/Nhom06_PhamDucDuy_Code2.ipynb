# %% [markdown]
# ## Ví Dụ 3: Áp dụng BO để tìm ra cấu trúc mạng tốt nhất cho 1 mạng CNN

# %%
# !pip install keras_tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (2.27.1)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras_tuner) (3.4)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import BayesianOptimization

# %% [markdown]
# Bộ dữ liệu CIFAR-10 gồm tổng cộng 60.000 hình ảnh màu (RGB), trong đó có 6.000 ảnh thuộc mỗi lớp. Bộ dữ liệu này đã được chia thành hai tập: tập huấn luyện (training set) với 50.000 hình ảnh và tập kiểm tra (test set) với 10.000 hình ảnh. Tập huấn luyện được sử dụng để đào tạo và điều chỉnh mô hình học máy, trong khi tập kiểm tra được sử dụng để đánh giá hiệu suất và khả năng tổng quát hóa của mô hình.
# Các vật thể trong Bộ:
#
# Airplane (Máy bay): Hình ảnh các máy bay từ các góc nhìn khác nhau.
#
# Automobile (Ô tô): Hình ảnh các ô tô, xe tải, xe hơi từ các góc nhìn khác nhau.
#
# Bird (Chim): Hình ảnh các loại chim từ các góc nhìn khác nhau.
#
# Cat (Mèo): Hình ảnh các con mèo từ các góc nhìn khác nhau.
#
# Deer (Hươu): Hình ảnh các con hươu từ các góc nhìn khác nhau.
#
# Dog (Chó): Hình ảnh các con chó từ các góc nhìn khác nhau.
#
# Frog (Ếch): Hình ảnh các con ếch từ các góc nhìn khác nhau.
#
# Horse (Ngựa): Hình ảnh các con ngựa từ các góc nhìn khác nhau.
#
# Ship (Tàu): Hình ảnh các loại tàu từ các góc nhìn khác nhau.
#
# Truck (Xe tải): Hình ảnh các xe tải từ các góc nhìn khác nhau.

# %%
# Tải và chuẩn bị dữ liệu CIFAR-10
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.InputLayer(input_shape=(32, 32, 3)))

    # Thêm các khối convolutional với số lượng và số lượng bộ lọc được tối ưu hóa bởi BO
    for i in range(hp.Int("conv_blocks", min_value=1, max_value=3, step=1)):
        model.add(layers.Conv2D(filters=hp.Int(f"filters_{i}", min_value=16, max_value=64, step=16),
                                kernel_size=(3, 3), padding="same", activation="relu"))
        model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(units=hp.Int("dense_units", min_value=32, max_value=128, step=32),
                           activation="relu"))

    model.add(layers.Dense(10, activation="softmax"))

    model.compile(optimizer=keras.optimizers.Adam(
        learning_rate=hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="log")),
        loss="categorical_crossentropy", metrics=["accuracy"])

    return model

# %%
# Tạo danh sách để lưu các giá trị
learning_rates = []
val_losses = []
val_accuracies = []

# Định nghĩa callback để lưu các giá trị sau mỗi epoch
class CustomCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        learning_rate = self.model.optimizer.lr.numpy()
        val_loss = logs["val_loss"]
        val_accuracy = logs["val_accuracy"]
        
        learning_rates.append(learning_rate)
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)


# Khởi tạo một đối tượng BayesianOptimization với hàm xây dựng mô hình và các thông số khác
tuner = BayesianOptimization(build_model,
                             objective="val_accuracy",
                             max_trials=10,
                             executions_per_trial=2,
                             directory="bayesian_optimization",
                             project_name="cnn_cifar10")

# Tìm kiếm các tham số tốt nhất cho mô hình và sử dụng callback để lưu giá trị
tuner.search(x_train, y_train,
             epochs=5,
             validation_data=(x_test, y_test),
             callbacks=[CustomCallback()])

# Lấy mô hình tốt nhất và đánh giá trên tập kiểm tra
best_model = tuner.get_best_models(num_models=1)[0]
best_model.evaluate(x_test, y_test)

# In ra learning rate và các chỉ số đánh giá sau mỗi epoch
for epoch in range(len(learning_rates)):
    print("Epoch:", epoch+1)
    print("Learning rate:", learning_rates[epoch])
    print("Validation loss:", val_losses[epoch])
    print("Validation accuracy:", val_accuracies[epoch])
    print()
# Out:
# Trial 10 Complete [00h 24m 34s]
# val_accuracy: 0.6865499913692474
#
# Best val_accuracy So Far: 0.6895999908447266
# Total elapsed time: 01h 59m 02s
# 313/313 [==============================] - 8s 23ms/step - loss: 0.8952 - accuracy: 0.6914
# Epoch: 1
# Learning rate: 0.0010882807
# Validation loss: 1.3241212368011475
# Validation accuracy: 0.5284000039100647
#
# Epoch: 2
# Learning rate: 0.0010882807
# Validation loss: 1.1664624214172363
# Validation accuracy: 0.5871999859809875
#
# Epoch: 3
# Learning rate: 0.0010882807
# Validation loss: 1.0525225400924683
# Validation accuracy: 0.6312999725341797
#
# Epoch: 4
# Learning rate: 0.0010882807
# Validation loss: 1.034347653388977
# Validation accuracy: 0.6388999819755554
#
# Epoch: 5
# Learning rate: 0.0010882807
# Validation loss: 0.9923528432846069
# Validation accuracy: 0.6542999744415283
#
# Epoch: 6
# Learning rate: 0.0010882807
# Validation loss: 1.3003382682800293
# Validation accuracy: 0.5338000059127808
#
# Epoch: 7
# Learning rate: 0.0010882807
# Validation loss: 1.1270145177841187
# Validation accuracy: 0.5976999998092651
#
# Epoch: 8
# Learning rate: 0.0010882807
# Validation loss: 1.074960470199585
# Validation accuracy: 0.6261000037193298
#
# Epoch: 9
# Learning rate: 0.0010882807
# Validation loss: 0.9859520792961121
# Validation accuracy: 0.6543999910354614
#
# Epoch: 10
# Learning rate: 0.0010882807
# Validation loss: 0.9926040768623352
# Validation accuracy: 0.6552000045776367
#
# Epoch: 11
# Learning rate: 0.0002502222
# Validation loss: 1.3648133277893066
# Validation accuracy: 0.511900007724762
#
# Epoch: 12
# Learning rate: 0.0002502222
# Validation loss: 1.2158535718917847
# Validation accuracy: 0.5702999830245972
#
# Epoch: 13
# Learning rate: 0.0002502222
# Validation loss: 1.163399577140808
# Validation accuracy: 0.5884000062942505
#
# Epoch: 14
# Learning rate: 0.0002502222
# Validation loss: 1.0805567502975464
# Validation accuracy: 0.6248999834060669
#
# Epoch: 15
# Learning rate: 0.0002502222
# Validation loss: 1.0736820697784424
# Validation accuracy: 0.6223999857902527
#
# Epoch: 16
# Learning rate: 0.0002502222
# Validation loss: 1.3604484796524048
# Validation accuracy: 0.5250999927520752
#
# Epoch: 17
# Learning rate: 0.0002502222
# Validation loss: 1.2614518404006958
# Validation accuracy: 0.5608999729156494
#
# Epoch: 18
# Learning rate: 0.0002502222
# Validation loss: 1.18678879737854
# Validation accuracy: 0.5823000073432922
#
# Epoch: 19
# Learning rate: 0.0002502222
# Validation loss: 1.1733486652374268
# Validation accuracy: 0.5896000266075134
#
# Epoch: 20
# Learning rate: 0.0002502222
# Validation loss: 1.1240928173065186
# Validation accuracy: 0.6075000166893005
#
# Epoch: 21
# Learning rate: 0.00058323535
# Validation loss: 1.2296987771987915
# Validation accuracy: 0.5651999711990356
#
# Epoch: 22
# Learning rate: 0.00058323535
# Validation loss: 1.0516877174377441
# Validation accuracy: 0.6338000297546387
#
# Epoch: 23
# Learning rate: 0.00058323535
# Validation loss: 0.9653392434120178
# Validation accuracy: 0.6657999753952026
#
# Epoch: 24
# Learning rate: 0.00058323535
# Validation loss: 0.9687759876251221
# Validation accuracy: 0.6662999987602234
#
# Epoch: 25
# Learning rate: 0.00058323535
# Validation loss: 0.9167113304138184
# Validation accuracy: 0.6877999901771545
#
# Epoch: 26
# Learning rate: 0.00058323535
# Validation loss: 1.2148710489273071
# Validation accuracy: 0.5658000111579895
#
# Epoch: 27
# Learning rate: 0.00058323535
# Validation loss: 1.0999051332473755
# Validation accuracy: 0.6078000068664551
#
# Epoch: 28
# Learning rate: 0.00058323535
# Validation loss: 0.9786319136619568
# Validation accuracy: 0.6553000211715698
#
# Epoch: 29
# Learning rate: 0.00058323535
# Validation loss: 0.9325763583183289
# Validation accuracy: 0.6748999953269958
#
# Epoch: 30
# Learning rate: 0.00058323535
# Validation loss: 0.8952165842056274
# Validation accuracy: 0.6913999915122986
#
# Epoch: 31
# Learning rate: 0.0027553942
# Validation loss: 1.4688355922698975
# Validation accuracy: 0.4767000079154968
#
# Epoch: 32
# Learning rate: 0.0027553942
# Validation loss: 1.3170055150985718
# Validation accuracy: 0.5264000296592712
#
# Epoch: 33
# Learning rate: 0.0027553942
# Validation loss: 1.28688383102417
# Validation accuracy: 0.5443999767303467
#
# Epoch: 34
# Learning rate: 0.0027553942
# Validation loss: 1.2905640602111816
# Validation accuracy: 0.5464000105857849
#
# Epoch: 35
# Learning rate: 0.0027553942
# Validation loss: 1.202735185623169
# Validation accuracy: 0.5796999931335449
#
# Epoch: 36
# Learning rate: 0.0027553942
# Validation loss: 1.3388432264328003
# Validation accuracy: 0.521399974822998
#
# Epoch: 37
# Learning rate: 0.0027553942
# Validation loss: 1.233832597732544
# Validation accuracy: 0.5655999779701233
#
# Epoch: 38
# Learning rate: 0.0027553942
# Validation loss: 1.3471276760101318
# Validation accuracy: 0.5457000136375427
#
# Epoch: 39
# Learning rate: 0.0027553942
# Validation loss: 1.223341941833496
# Validation accuracy: 0.5651999711990356
#
# Epoch: 40
# Learning rate: 0.0027553942
# Validation loss: 1.1638519763946533
# Validation accuracy: 0.593999981880188
#
# Epoch: 41
# Learning rate: 0.0042425836
# Validation loss: 1.5011858940124512
# Validation accuracy: 0.4553999900817871
#
# Epoch: 42
# Learning rate: 0.0042425836
# Validation loss: 1.2665159702301025
# Validation accuracy: 0.5422000288963318
#
# Epoch: 43
# Learning rate: 0.0042425836
# Validation loss: 1.2297807931900024
# Validation accuracy: 0.5595999956130981
#
# Epoch: 44
# Learning rate: 0.0042425836
# Validation loss: 1.2508692741394043
# Validation accuracy: 0.555400013923645
#
# Epoch: 45
# Learning rate: 0.0042425836
# Validation loss: 1.1310423612594604
# Validation accuracy: 0.6003999710083008
#
# Epoch: 46
# Learning rate: 0.0042425836
# Validation loss: 1.5485109090805054
# Validation accuracy: 0.4221999943256378
#
# Epoch: 47
# Learning rate: 0.0042425836
# Validation loss: 1.4588286876678467
# Validation accuracy: 0.46639999747276306
#
# Epoch: 48
# Learning rate: 0.0042425836
# Validation loss: 1.3437230587005615
# Validation accuracy: 0.5060999989509583
#
# Epoch: 49
# Learning rate: 0.0042425836
# Validation loss: 1.3042690753936768
# Validation accuracy: 0.5267000198364258
#
# Epoch: 50
# Learning rate: 0.0042425836
# Validation loss: 1.2813637256622314
# Validation accuracy: 0.5375000238418579
#
# Epoch: 51
# Learning rate: 0.000121660814
# Validation loss: 1.5352091789245605
# Validation accuracy: 0.4675999879837036
#
# Epoch: 52
# Learning rate: 0.000121660814
# Validation loss: 1.3699871301651
# Validation accuracy: 0.5162000060081482
#
# Epoch: 53
# Learning rate: 0.000121660814
# Validation loss: 1.2944170236587524
# Validation accuracy: 0.5450000166893005
#
# Epoch: 54
# Learning rate: 0.000121660814
# Validation loss: 1.254647970199585
# Validation accuracy: 0.5602999925613403
#
# Epoch: 55
# Learning rate: 0.000121660814
# Validation loss: 1.2288023233413696
# Validation accuracy: 0.5687999725341797
#
# Epoch: 56
# Learning rate: 0.000121660814
# Validation loss: 1.5171843767166138
# Validation accuracy: 0.47380000352859497
#
# Epoch: 57
# Learning rate: 0.000121660814
# Validation loss: 1.4001190662384033
# Validation accuracy: 0.5078999996185303
#
# Epoch: 58
# Learning rate: 0.000121660814
# Validation loss: 1.297232985496521
# Validation accuracy: 0.5504999756813049
#
# Epoch: 59
# Learning rate: 0.000121660814
# Validation loss: 1.2539924383163452
# Validation accuracy: 0.5569999814033508
#
# Epoch: 60
# Learning rate: 0.000121660814
# Validation loss: 1.2075107097625732
# Validation accuracy: 0.5767999887466431
#
# Epoch: 61
# Learning rate: 0.0018516864
# Validation loss: 1.1743018627166748
# Validation accuracy: 0.5727999806404114
#
# Epoch: 62
# Learning rate: 0.0018516864
# Validation loss: 1.0030899047851562
# Validation accuracy: 0.6470999717712402
#
# Epoch: 63
# Learning rate: 0.0018516864
# Validation loss: 0.9232509732246399
# Validation accuracy: 0.6739000082015991
#
# Epoch: 64
# Learning rate: 0.0018516864
# Validation loss: 0.9367019534111023
# Validation accuracy: 0.6819000244140625
#
# Epoch: 65
# Learning rate: 0.0018516864
# Validation loss: 0.8902410268783569
# Validation accuracy: 0.6952999830245972
#
# Epoch: 66
# Learning rate: 0.0018516864
# Validation loss: 1.1311748027801514
# Validation accuracy: 0.5993000268936157
#
# Epoch: 67
# Learning rate: 0.0018516864
# Validation loss: 1.009459376335144
# Validation accuracy: 0.6417999863624573
#
# Epoch: 68
# Learning rate: 0.0018516864
# Validation loss: 0.959701657295227
# Validation accuracy: 0.6650999784469604
#
# Epoch: 69
# Learning rate: 0.0018516864
# Validation loss: 0.9620125889778137
# Validation accuracy: 0.6693999767303467
#
# Epoch: 70
# Learning rate: 0.0018516864
# Validation loss: 0.9378622174263
# Validation accuracy: 0.6777999997138977
